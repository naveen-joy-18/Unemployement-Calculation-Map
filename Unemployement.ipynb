# %%
import pandas as pd
# !pip install folium

# Load the first dataset
data = pd.read_csv(r'C:\Users\navee\Desktop\Internship Project\Unemployment_Rate_upto_11_2020.csv')

# Data Exploration
print(data.head())
print(data.info())
print(data.describe())

# Visualize Trends
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
for region in data['Region'].unique():
    region_data = data[data['Region'] == region]
    plt.plot(region_data['Date'], region_data['Estimated Unemployment Rate (%)'], label=region)
plt.xlabel('Date')
plt.ylabel('Unemployment Rate (%)')
plt.title('Unemployment Rate Trends by Region')
plt.legend()
plt.show()

# Select only numeric columns for correlation analysis
numeric_data = data.select_dtypes(include='float64')

# Correlation Analysis
correlation_matrix = numeric_data.corr()
print(correlation_matrix)

# Forecasting (Example using ARIMA)
from statsmodels.tsa.arima_model import ARIMA

# Add your ARIMA forecasting code here

# Geospatial Analysis (Example using folium)
import folium

map = folium.Map(location=[20.5937, 78.9629], zoom_start=5)
for index, row in data.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], popup=row['Region']).add_to(map)
map.save('unemployment_map.html')
# Out:
# ...
#    ---------------------------------------- 0.0/100.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/100.0 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/100.0 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/100.0 kB ? eta -:--:--
#    ----------- --------------------------- 30.7/100.0 kB 187.9 kB/s eta 0:00:01
#    --------------- ----------------------- 41.0/100.0 kB 196.9 kB/s eta 0:00:01
#    --------------------------- ----------- 71.7/100.0 kB 302.7 kB/s eta 0:00:01
#    -------------------------------------- 100.0/100.0 kB 337.5 kB/s eta 0:00:00
# ...
#            Region        Date Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh  31-01-2020         M                             5.48
# 1  Andhra Pradesh  29-02-2020         M                             5.83
# 2  Andhra Pradesh  31-03-2020         M                             5.79
# 3  Andhra Pradesh  30-04-2020         M                            20.51
# ...
